# %%
import numpy as np

# %%
lst_marks=[34,45,45,56,67,78,90,98,87,86,76,75,65,64,54,43,32,66,77,88,99]
minimum,Q1,median,Q3,maximum=np.quantile(lst_marks,[0.0,0.25,0.50,0.75,1.0])

# %%
minimum
# Out:
# 32.0

# %%
Q1,median,Q3
# Out:
# (54.0, 67.0, 86.0)

# %%
IQR=Q3-Q1

# %%
lower_fenz=Q1-1.5*(IQR)
higher_fenz=Q3+1.5*(IQR)

# %%
lower_fenz,higher_fenz
# Out:
# (6.0, 134.0)

# %%
import matplotlib.pyplot as plt
plt.boxplot(lst_marks)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c777eefaa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c777eeff80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c777eeea80>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c778ef0620>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c778ef0920>],
#  'means': []}

# %%
import seaborn as sns
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks=[2,3,1,34,45,45,56,67,78,90,98,87,86,76,75,65,64,54,43,32,66,77,88,99,400,500,600]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
